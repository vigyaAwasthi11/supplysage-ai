# %%
# %sql
SHOW TABLES IN supplysage_bronze;

# %%
# %sql
SELECT 'bronze_m5_calendar' AS table_name, COUNT(*) AS row_count
FROM supplysage_bronze.bronze_m5_calendar

UNION ALL

SELECT 'bronze_m5_sell_prices' AS table_name, COUNT(*) AS row_count
FROM supplysage_bronze.bronze_m5_sell_prices

UNION ALL

SELECT 'bronze_m5_sales_train_validation' AS table_name, COUNT(*) AS row_count
FROM supplysage_bronze.bronze_m5_sales_train_validation;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_m5_sales_train_validation
LIMIT 5;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_m5_sell_prices
LIMIT 5;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_m5_calendar
LIMIT 5;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_retail_inventory
LIMIT 5;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_data_co_supply_chain_dataset
LIMIT 5;

# %%
# %sql
SELECT *
FROM supplysage_bronze.bronze_description_data_co_supply_chain
LIMIT 5;
